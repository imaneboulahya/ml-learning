# %%
#dataset link : https://www.kaggle.com/datasets/kundanbedmutha/exam-score-prediction-dataset

# %%
#importation de la librairie pandas

# %%
import pandas as pd

# %%
#importation du dataset

# %%
df = pd.read_csv("Exam_Score_Prediction.csv")

# %%
#afficher les 5 premieres lignes

# %%
df.head()
# Out:
#    student_id  age  gender   course  study_hours  class_attendance  \
# 0           1   17    male  diploma         2.78              92.9
# 1           2   23   other      bca         3.37              64.8
# 2           3   22    male     b.sc         7.88              76.8
# 3           4   20   other  diploma         0.67              48.4
# 4           5   20  female  diploma         0.89              71.6
#
#   internet_access  sleep_hours sleep_quality   study_method facility_rating  \
# 0             yes          7.4          poor       coaching             low
# 1             yes          4.6       average  online videos          medium
# 2             yes          8.5          poor       coaching            high
# 3             yes          5.8       average  online videos             low
# 4             yes          9.8          poor       coaching             low
#
#   exam_difficulty  exam_score
# 0            hard        58.9
# 1        moderate        54.8
# ...

# %%
#afficher la somme des valeurs manquantes si elles existent

# %%
df.isnull().sum()
# Out:
# student_id          0
# age                 0
# gender              0
# course              0
# study_hours         0
# class_attendance    0
# internet_access     0
# sleep_hours         0
# sleep_quality       0
# study_method        0
# facility_rating     0
# exam_difficulty     0
# exam_score          0
# dtype: int64

# %%
# the feature here is exam_score

# %%
#on separe feature et target

# %%
x = df.drop("exam_score", axis=1)

# %%
y = df["exam_score"]

# %%
#on donne 80% du data pour le training et 20% pour le teste

# %%
#on importe la librairie

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_test=42)
