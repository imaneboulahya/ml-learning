# %% [raw]
# import pandas as pd

# %%
df = pd.read_csv('data/laptops.csv')

# %%
df.head()
# Out:
#                                               Laptop Status   Brand  \
# 0  ASUS ExpertBook B1 B1502CBA-EJ0436X Intel Core...    New    Asus
# 1  Alurin Go Start Intel Celeron N4020/8GB/256GB ...    New  Alurin
# 2  ASUS ExpertBook B1 B1502CBA-EJ0424X Intel Core...    New    Asus
# 3  MSI Katana GF66 12UC-082XES Intel Core i7-1270...    New     MSI
# 4  HP 15S-FQ5085NS Intel Core i5-1235U/16GB/512GB...    New      HP
#
#         Model            CPU  RAM  Storage Storage type       GPU  Screen  \
# 0  ExpertBook  Intel Core i5    8      512          SSD       NaN    15.6
# 1          Go  Intel Celeron    8      256          SSD       NaN    15.6
# 2  ExpertBook  Intel Core i3    8      256          SSD       NaN    15.6
# 3      Katana  Intel Core i7   16     1000          SSD  RTX 3050    15.6
# 4         15S  Intel Core i5   16      512          SSD       NaN    15.6
#
#   Touch  Final Price
# 0    No      1009.00
# 1    No       299.00
# 2    No       789.00
# 3    No      1199.00
# 4    No       669.01

# %%
df.shape
# Out:
# (2160, 12)

# %%
df['Brand'].nunique()
# Out:
# 27

# %%
df.isnull().sum()
# Out:
# Laptop             0
# Status             0
# Brand              0
# Model              0
# CPU                0
# RAM                0
# Storage            0
# Storage type      42
# GPU             1371
# Screen             4
# Touch              0
# Final Price        0
# dtype: int64

# %%
Dell_laptop = df[df['Brand'] == 'Dell']

# %%
max(Dell_laptop['Final Price'])
# Out:
# 3936.0

# %%
df['Screen'].median()
# Out:
# 15.6

# %%
df['Screen'].mode()[0]
# Out:
# np.float64(15.6)

# %%
df['Screen'] = df['Screen'].fillna(df['Screen'].mode()[0])

# %%
df.isnull().sum()
# Out:
# Laptop             0
# Status             0
# Brand              0
# Model              0
# CPU                0
# RAM                0
# Storage            0
# Storage type      42
# GPU             1371
# Screen             0
# Touch              0
# Final Price        0
# dtype: int64

# %%
df.head()
# Out:
#                                               Laptop Status   Brand  \
# 0  ASUS ExpertBook B1 B1502CBA-EJ0436X Intel Core...    New    Asus
# 1  Alurin Go Start Intel Celeron N4020/8GB/256GB ...    New  Alurin
# 2  ASUS ExpertBook B1 B1502CBA-EJ0424X Intel Core...    New    Asus
# 3  MSI Katana GF66 12UC-082XES Intel Core i7-1270...    New     MSI
# 4  HP 15S-FQ5085NS Intel Core i5-1235U/16GB/512GB...    New      HP
#
#         Model            CPU  RAM  Storage Storage type       GPU  Screen  \
# 0  ExpertBook  Intel Core i5    8      512          SSD       NaN    15.6
# 1          Go  Intel Celeron    8      256          SSD       NaN    15.6
# 2  ExpertBook  Intel Core i3    8      256          SSD       NaN    15.6
# 3      Katana  Intel Core i7   16     1000          SSD  RTX 3050    15.6
# 4         15S  Intel Core i5   16      512          SSD       NaN    15.6
#
#   Touch  Final Price
# 0    No      1009.00
# 1    No       299.00
# 2    No       789.00
# 3    No      1199.00
# 4    No       669.01

# %%
df['Storage type'] = df['Storage type'].fillna(df['Storage type'].mode()[0])

# %%
df.isnull().sum()
# Out:
# Laptop             0
# Status             0
# Brand              0
# Model              0
# CPU                0
# RAM                0
# Storage            0
# Storage type       0
# GPU             1371
# Screen             0
# Touch              0
# Final Price        0
# dtype: int64

# %%
df['GPU'] = df['GPU'].fillna(df['GPU'].mode()[0])

# %%
df.isnull().sum()
# Out:
# Laptop          0
# Status          0
# Brand           0
# Model           0
# CPU             0
# RAM             0
# Storage         0
# Storage type    0
# GPU             0
# Screen          0
# Touch           0
# Final Price     0
# dtype: int64

# %%
df.head()
# Out:
#                                               Laptop Status   Brand  \
# 0  ASUS ExpertBook B1 B1502CBA-EJ0436X Intel Core...    New    Asus
# 1  Alurin Go Start Intel Celeron N4020/8GB/256GB ...    New  Alurin
# 2  ASUS ExpertBook B1 B1502CBA-EJ0424X Intel Core...    New    Asus
# 3  MSI Katana GF66 12UC-082XES Intel Core i7-1270...    New     MSI
# 4  HP 15S-FQ5085NS Intel Core i5-1235U/16GB/512GB...    New      HP
#
#         Model            CPU  RAM  Storage Storage type       GPU  Screen  \
# 0  ExpertBook  Intel Core i5    8      512          SSD  RTX 3050    15.6
# 1          Go  Intel Celeron    8      256          SSD  RTX 3050    15.6
# 2  ExpertBook  Intel Core i3    8      256          SSD  RTX 3050    15.6
# 3      Katana  Intel Core i7   16     1000          SSD  RTX 3050    15.6
# 4         15S  Intel Core i5   16      512          SSD  RTX 3050    15.6
#
#   Touch  Final Price
# 0    No      1009.00
# 1    No       299.00
# 2    No       789.00
# 3    No      1199.00
# 4    No       669.01

# %%
df.drop('Laptop', axis=1)
# Out:
#            Status   Brand       Model                CPU  RAM  Storage  \
# 0             New    Asus  ExpertBook      Intel Core i5    8      512
# 1             New  Alurin          Go      Intel Celeron    8      256
# 2             New    Asus  ExpertBook      Intel Core i3    8      256
# 3             New     MSI      Katana      Intel Core i7   16     1000
# 4             New      HP         15S      Intel Core i5   16      512
# ...           ...     ...         ...                ...  ...      ...
# 2155  Refurbished   Razer       Blade      Intel Core i7   16     1000
# 2156  Refurbished   Razer       Blade      Intel Core i7   16     1000
# 2157  Refurbished   Razer       Blade      Intel Core i7   32     1000
# 2158  Refurbished   Razer        Book  Intel Evo Core i7   16     1000
# 2159  Refurbished   Razer        Book  Intel Evo Core i7   16      256
#
#      Storage type       GPU  Screen Touch  Final Price
# 0             SSD  RTX 3050    15.6    No      1009.00
# 1             SSD  RTX 3050    15.6    No       299.00
# 2             SSD  RTX 3050    15.6    No       789.00
# 3             SSD  RTX 3050    15.6    No      1199.00
# 4             SSD  RTX 3050    15.6    No       669.01
# ...           ...       ...     ...   ...          ...
# 2155          SSD  RTX 3060    17.3    No      2699.99
# 2156          SSD  RTX 3070    17.3    No      2899.99
# 2157          SSD  RTX 3080    17.3    No      3399.99
# 2158          SSD  RTX 3050    13.4   Yes      1899.99
# 2159          SSD  RTX 3050    13.4   Yes      1699.99
#
# [2160 rows x 11 columns]

# %%
df = df.drop('Laptop', axis=1)

# %%
df.head()
# Out:
#   Status   Brand       Model            CPU  RAM  Storage Storage type  \
# 0    New    Asus  ExpertBook  Intel Core i5    8      512          SSD
# 1    New  Alurin          Go  Intel Celeron    8      256          SSD
# 2    New    Asus  ExpertBook  Intel Core i3    8      256          SSD
# 3    New     MSI      Katana  Intel Core i7   16     1000          SSD
# 4    New      HP         15S  Intel Core i5   16      512          SSD
#
#         GPU  Screen Touch  Final Price
# 0  RTX 3050    15.6    No      1009.00
# 1  RTX 3050    15.6    No       299.00
# 2  RTX 3050    15.6    No       789.00
# 3  RTX 3050    15.6    No      1199.00
# 4  RTX 3050    15.6    No       669.01

# %%
data = df.copy()

# %%
data.head()
# Out:
#   Status   Brand       Model            CPU  RAM  Storage Storage type  \
# 0    New    Asus  ExpertBook  Intel Core i5    8      512          SSD
# 1    New  Alurin          Go  Intel Celeron    8      256          SSD
# 2    New    Asus  ExpertBook  Intel Core i3    8      256          SSD
# 3    New     MSI      Katana  Intel Core i7   16     1000          SSD
# 4    New      HP         15S  Intel Core i5   16      512          SSD
#
#         GPU  Screen Touch  Final Price
# 0  RTX 3050    15.6    No      1009.00
# 1  RTX 3050    15.6    No       299.00
# 2  RTX 3050    15.6    No       789.00
# 3  RTX 3050    15.6    No      1199.00
# 4  RTX 3050    15.6    No       669.01

# %%
data.dtypes
# Out:
# Status           object
# Brand            object
# Model            object
# CPU              object
# RAM               int64
# Storage           int64
# Storage type     object
# GPU              object
# Screen          float64
# Touch            object
# Final Price     float64
# dtype: object

# %%
data.select_dtypes('object')
# Out:
#            Status   Brand       Model                CPU Storage type  \
# 0             New    Asus  ExpertBook      Intel Core i5          SSD
# 1             New  Alurin          Go      Intel Celeron          SSD
# 2             New    Asus  ExpertBook      Intel Core i3          SSD
# 3             New     MSI      Katana      Intel Core i7          SSD
# 4             New      HP         15S      Intel Core i5          SSD
# ...           ...     ...         ...                ...          ...
# 2155  Refurbished   Razer       Blade      Intel Core i7          SSD
# 2156  Refurbished   Razer       Blade      Intel Core i7          SSD
# 2157  Refurbished   Razer       Blade      Intel Core i7          SSD
# 2158  Refurbished   Razer        Book  Intel Evo Core i7          SSD
# 2159  Refurbished   Razer        Book  Intel Evo Core i7          SSD
#
#            GPU Touch
# 0     RTX 3050    No
# 1     RTX 3050    No
# 2     RTX 3050    No
# 3     RTX 3050    No
# 4     RTX 3050    No
# ...        ...   ...
# 2155  RTX 3060    No
# 2156  RTX 3070    No
# 2157  RTX 3080    No
# 2158  RTX 3050   Yes
# 2159  RTX 3050   Yes
#
# [2160 rows x 7 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
data['Status'] = le.fit_transform(data['Status'])

# %%
data['Brand']= le.fit_transform(data['Brand'])

# %%
data['Model'] = le.fit_transform(data['Model'])

# %%
data['CPU'] = le.fit_transform(data['CPU'])

# %%
data['Storage type'] = le.fit_transform(data['Storage type'])

# %%
data['GPU'] = le.fit_transform(data['GPU'])

# %%
data['Touch'] = le.fit_transform(data['Touch'])

# %%
data.dtypes
# Out:
# Status            int64
# Brand             int64
# Model             int64
# CPU               int64
# RAM               int64
# Storage           int64
# Storage type      int64
# GPU               int64
# Screen          float64
# Touch             int64
# Final Price     float64
# dtype: object

# %%
from sklearn.model_selection import train_test_split

# %%
x = data.drop(['Final Price'], axis = 1)

# %%
y = data['Final Price']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
mae = mean_absolute_error(y_test, y_pred)

# %%
mse = mean_squared_error(y_test, y_pred)

# %%
r2 = r2_score(y_test, y_pred)

# %%
print(f"mae : {mae}")
# Out:
# mae : 397.3135745778797

# %%
print(f"mse : {mse}")
# Out:
# mse : 320668.49044737866

# %%
print(f"r2 : {r2}")
# Out:
# r2 : 0.6522513997010992

# %%
df.head()
# Out:
#   Status   Brand       Model            CPU  RAM  Storage Storage type  \
# 0    New    Asus  ExpertBook  Intel Core i5    8      512          SSD
# 1    New  Alurin          Go  Intel Celeron    8      256          SSD
# 2    New    Asus  ExpertBook  Intel Core i3    8      256          SSD
# 3    New     MSI      Katana  Intel Core i7   16     1000          SSD
# 4    New      HP         15S  Intel Core i5   16      512          SSD
#
#         GPU  Screen Touch  Final Price
# 0  RTX 3050    15.6    No      1009.00
# 1  RTX 3050    15.6    No       299.00
# 2  RTX 3050    15.6    No       789.00
# 3  RTX 3050    15.6    No      1199.00
# 4  RTX 3050    15.6    No       669.01

# %%
df.dtypes
# Out:
# Status           object
# Brand            object
# Model            object
# CPU              object
# RAM               int64
# Storage           int64
# Storage type     object
# GPU              object
# Screen          float64
# Touch            object
# Final Price     float64
# dtype: object
